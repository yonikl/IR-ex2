# %%
import torch
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split

base_path = 'IR-Newspapers-files\\IR-files'

labels_list = {'A-J' : 0, 'BBC' : 1, 'J-P' : 2, 'NY-T' : 3}
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(str(device))
# Out:
# cuda

# %%
import pandas as pd
import os


def apply_to_all_matrices(classifier):
    for dir in os.listdir(base_path):
        if dir == 'TF-IDF':
            clean_matrices = []
            lemma_matrices = []
            for file in sorted(os.listdir(f'{base_path}\\{dir}')):
                if 'clean' in file:
                    clean_matrices.append(pd.read_excel(f'{base_path}\\{dir}\\{file}').drop(columns=['DocumentIndex']))
                elif 'lemma' in file:
                    lemma_matrices.append(pd.read_excel(f'{base_path}\\{dir}\\{file}').drop(columns=['DocumentIndex']))


            shapes = [i.shape[0] for i in clean_matrices]

            y = []
            for i, j in enumerate(shapes):
                y = y + [i] * j
            y = np.array(y)


            clean_df = pd.concat(clean_matrices, ignore_index=True)
            lemma_df = pd.concat(lemma_matrices, ignore_index=True)



            print(f'{"-"*20}TF-IDF clean{"-"*20}')
            classifier(clean_df.to_numpy(dtype=np.float32), y,'TF-IDF clean')
            print(f'{"-"*20}TF-IDF lemma{"-"*20}')
            classifier(lemma_df.to_numpy(dtype=np.float32), y, 'TF-IDF lemma')

        else:
            for matrix in os.listdir(f'{base_path}\\{dir}'):
                df = pd.read_csv(f'{base_path}\\{dir}\\{matrix}')

                y = df['Sheet'].map(labels_list)

                df.drop(['RowIndex', 'Sheet'], axis=1, inplace=True)


                print(f'{"-"*20}{matrix}{"-"*20}')
                classifier(df.to_numpy(dtype=np.float32), y.to_numpy(), matrix)

# %%
import sys
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
import os

def train_model(model, train_loader, val_loader, criterion, optimizer, max_epochs=15, patience=3, save_path='best_model.pth'):
    """
    Train the model with early stopping based on accuracy and save the best model.

    Parameters:
    - model: The neural network model.
    - train_loader: DataLoader for the training set.
    - val_loader: DataLoader for the validation set.
    - criterion: Loss function.
    - optimizer: Optimizer.
    - device: Device to run the training on ("cpu" or "cuda").
    - max_epochs: Maximum number of training epochs.
    - patience: Early stopping patience.
    - save_path: Path to save the best model.

    Returns:
    - model: The best trained model.
    """
    best_accuracy = 0.0
    epochs_no_improve = 0

    model.to(device)
    for epoch in range(max_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * inputs.size(0)
        train_loss /= len(train_loader.dataset)

        # Validation phase
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs, 1)  # Multi-class prediction
                correct += (predicted == targets).sum().item()
                total += targets.size(0)
        val_accuracy = correct / total

        print(f"Epoch {epoch+1}/{max_epochs} | Train Loss: {train_loss:.4f} | Val Accuracy: {val_accuracy:.4f}")


        # Check early stopping based on accuracy
        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            epochs_no_improve = 0
            torch.save(model.state_dict(), save_path)
            print(f"Model saved at epoch {epoch+1} with accuracy: {val_accuracy:.4f}")
        else:
            epochs_no_improve += 1
            print(f"No improvement for {epochs_no_improve} epoch(s)")

        if epochs_no_improve >= patience:
            print("Early stopping triggered.")
            break

    # Load the best model
    model.load_state_dict(torch.load(save_path, weights_only=True))
    print(f"Best Validation Accuracy: {best_accuracy:.4f}")
    return model.to(device)

# %%
from dataset import CDataset
from ANN import ANN
def train_ANN(X, y, name):
    dataset = CDataset(X, y)

    train_size = int(0.72 * len(dataset))
    val_size = int(0.08 * len(dataset))
    test_size = len(dataset) - train_size - val_size

    ANN_Relu = ANN(X.shape[1], 'relu')
    ANN_Gelu = ANN(X.shape[1], 'gelu')

    train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32)
    test_loader = DataLoader(test_dataset, batch_size=32)

    criterion = nn.CrossEntropyLoss()  # Multi-class classification loss
    optimizer_relu = torch.optim.Adam(ANN_Relu.parameters(), lr=0.001)
    optimizer_gelu = torch.optim.Adam(ANN_Gelu.parameters(), lr=0.001)

    trained_relu_model = train_model(ANN_Relu, train_loader, val_loader, criterion, optimizer_relu, save_path=f'{name}_best_relu_model.pth')
    trained_gelu_model = train_model(ANN_Gelu, train_loader, val_loader, criterion, optimizer_gelu, save_path=f'{name}_best_gelu_model.pth')

     # Evaluate on test set
    trained_relu_model.eval()
    trained_gelu_model.eval()
    correct_relu = 0
    correct_gelu = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs_relu = trained_relu_model(inputs)
            outputs_gelu = trained_gelu_model(inputs)
            _, predicted_relu = torch.max(outputs_relu, 1)
            _, predicted_gelu = torch.max(outputs_gelu, 1)
            correct_relu += (predicted_relu == targets).sum().item()
            correct_gelu += (predicted_gelu == targets).sum().item()
            total += targets.size(0)
    test_accuracy_relu = correct_relu / total
    test_accuracy_gelu = correct_gelu / total
    print(f"Test Relu Accuracy: {test_accuracy_relu:.4f}")
    print(f"Test Gelu Accuracy: {test_accuracy_gelu:.4f}")

# %%
apply_to_all_matrices(train_ANN)
# Out:
# --------------------bert_withIDF.csv--------------------
# Epoch 1/15 | Train Loss: 0.9374 | Val Accuracy: 0.8396
# Model saved at epoch 1 with accuracy: 0.8396
# Epoch 2/15 | Train Loss: 0.3139 | Val Accuracy: 0.9465
# Model saved at epoch 2 with accuracy: 0.9465
# Epoch 3/15 | Train Loss: 0.1686 | Val Accuracy: 0.9679
# Model saved at epoch 3 with accuracy: 0.9679
# Epoch 4/15 | Train Loss: 0.1105 | Val Accuracy: 0.9733
# Model saved at epoch 4 with accuracy: 0.9733
# Epoch 5/15 | Train Loss: 0.0741 | Val Accuracy: 0.9412
# No improvement for 1 epoch(s)
# Epoch 6/15 | Train Loss: 0.0681 | Val Accuracy: 0.9786
# Model saved at epoch 6 with accuracy: 0.9786
# Epoch 7/15 | Train Loss: 0.0402 | Val Accuracy: 0.9679
# No improvement for 1 epoch(s)
# Epoch 8/15 | Train Loss: 0.0303 | Val Accuracy: 0.9786
# No improvement for 2 epoch(s)
# Epoch 9/15 | Train Loss: 0.0282 | Val Accuracy: 0.9679
# No improvement for 3 epoch(s)
# Early stopping triggered.
# Best Validation Accuracy: 0
# No improvement for 3 epoch(s)
# Early stopping triggered.
# Best Validation Accuracy: 0.8503
# Test Relu Accuracy: 0.8277
# Test Gelu Accuracy: 0.8277
# --------------------w2v_clean_withIDF_withStopWords.csv--------------------
# Epoch 1/15 | Train Loss: 1.3468 | Val Accuracy: 0.4011
# Model saved at epoch 1 with accuracy: 0.4011
# Epoch 2/15 | Train Loss: 1.0255 | Val Accuracy: 0.5668
# Model saved at epoch 2 with accuracy: 0.5668
# Epoch 3/15 | Train Loss: 0.8093 | Val Accuracy: 0.7059
# Model saved at epoch 3 with accuracy: 0.7059
# Epoch 4/15 | Train Loss: 0.6959 | Val Accuracy: 0.6631
# No improvement for 1 epoch(s)
# Epoch 5/15 | Train Loss: 0.6138 | Val Accuracy: 0.7754
# Model saved at epoch 5 with accuracy: 0.7754
# Epoch 6/15 | Train Loss: 0.5136 | Val Accuracy: 0.7326
# No improvement for 1 epoch(s)
# Epoch 7/15 | Train Loss: 0.4576 | Val Accuracy: 0.7326
# No improvement for 2 epoch(s)
# Epoch 8/15 | Train Loss: 0.3823 | Val Accuracy: 0.7968
# Model saved at epoch 8 with accuracy: 0.7968
# Epoch 9/15 | Train Loss: 0.3118 | Val Accuracy: 0.7807
# No improvement for 1 epoch(s)
# Epoch 10/15 | Train Loss: 0.2651 | Val Accuracy: 0.8128
# Model saved at epoch 10 with accuracy: 0.8128
# Epoch 11/15 | Train Loss: 0.2273 | Val Accuracy: 0.8075
# No improvement for 1 epoch(s)
# Epoch 12/15 | Train Loss: 0.1929 | Val Accuracy: 0.8075
# No improvement for 2 epoch(s)
# Epoch 13/15 | Train Loss: 0.1740 | Val Accuracy: 0.8235
# Model saved at epoch 13 with accuracy: 0.8235
# Epoch 14/15 | Train Loss: 0.1310 | Val Accuracy: 0.8021
# No improvement for 1 epoch(s)
# Epoch 15/15 | Train Loss: 0.1138 | Val Accuracy: 0.8289
# Model saved at epoch 15 with accuracy: 0.8289
# Best Validation Accuracy: 0.8289
# Epoch 1/15 | Train Loss: 1.3557 | Val Accuracy: 0.3583
# Model saved at epoch 1 with accuracy: 0.3583
# Epoch 2/15 | Train Loss: 1.0822 | Val Accuracy: 0.5829
# Model saved at epoch 2 with accuracy: 0.5829
# Epoch 3/15 | Train Loss: 0.8761 | Val Accuracy: 0.6364
# Model saved at epoch 3 with accuracy: 0.6364
# Epoch 4/15 | Train Loss: 0.7907 | Val Accuracy: 0.6845
# Model saved at epoch 4 with accuracy: 0.6845
# Epoch 5/15 | Train Loss: 0.6960 | Val Accuracy: 0.7112
# Model saved at epoch 5 with accuracy: 0.7112
# Epoch 6/15 | Train Loss: 0.6218 | Val Accuracy: 0.7273
# Model saved at epoch 6 with accuracy: 0.7273
# Epoch 7/15 | Train Loss: 0.5638 | Val Accuracy: 0.7540
# Model saved at epoch 7 with accuracy: 0.7540
# Epoch 5/15 | Train Loss: 0.7136 | Val Accuracy: 0.7112
# Model saved at epoch 5 with accuracy: 0.7112
# Epoch 6/15 | Train Loss: 0.6170 | Val Accuracy: 0.7594
# Model saved at epoch 6 with accuracy: 0.7594
# Epoch 7/15 | Train Loss: 0.5495 | Val Accuracy: 0.7166
# No improvement for 1 epoch(s)
# Epoch 8/15 | Train Loss: 0.4971 | Val Accuracy: 0.7647
# Model saved at epoch 8 with accuracy: 0.7647
# Epoch 9/15 | Train Loss: 0.4485 | Val Accuracy: 0.7594
# No improvement for 1 epoch(s)
# Epoch 10/15 | Train Loss: 0.4129 | Val Accuracy: 0.8289
# Model saved at epoch 10 with accuracy: 0.8289
# Epoch 11/15 | Train Loss: 0.3742 | Val Accuracy: 0.7968
# No improvement for 1 epoch(s)
# Epoch 12/15 | Train Loss: 0.3384 | Val Accuracy: 0.7968
# No improvement for 2 epoch(s)
# Epoch 13/15 | Train Loss: 0.3075 | Val Accuracy: 0.8289
# No improvement for 3 epoch(s)
# Early stopping triggered.
# Best Validation Accuracy: 0.8289
# Test Relu Accuracy: 0.8128
# Test Gelu Accuracy: 0.8340
# --------------------w2v_clean_withoutIdf_withStopWords.csv--------------------
# Epoch 1/15 | Train Loss: 1.3538 | Val Accuracy: 0.3904
# Model saved at epoch 1 with accuracy: 0.3904
# Epoch 2/15 | Train Loss: 1.0725 | Val Accuracy: 0.4492
# Model saved at epoch 2 with accuracy: 0.4492
# Epoch 3/15 | Train Loss: 0.9153 | Val Accuracy: 0.5455
# Model saved at epoch 3 with accuracy: 0.5455
# Epoch 4/15 | Train Loss: 0.8515 | Val Accuracy: 0.5615
# Model saved at epoch 4 with accuracy: 0.5615
# Epoch 5/15 | Train Loss: 0.8230 | Val Accuracy: 0.5829
# Model saved at epoch 5 with accuracy: 0.5829
# Epoch 6/15 | Train Loss: 0.7511 | Val Accuracy: 0.6578
# Model saved at epoch 6 with accuracy: 0.6578
# Epoch 7/15 | Train Loss: 0.7091 | Val Accuracy: 0.6791
# Model saved at epoch 7 with accuracy: 0.6791
# Epoch 8/15 | Train Loss: 0.6624 | Val Accuracy: 0.7219
# Model saved at epoch 8 with accuracy: 0.7219
# Epoch 9/15 | Train Loss: 0.6030 | Val Accuracy: 0.7594
# Model saved at epoch 9 with accuracy: 0.7594
# Epoch 10/15 | Train Loss: 0.5665 | Val Accuracy: 0.7647
# Model saved at epoch 10 with accuracy: 0.7647
# Epoch 11/15 | Train Loss: 0.5223 | Val Accuracy: 0.7754
# Model saved at epoch 11 with accuracy: 0.7754
# Epoch 12/15 | Train Loss: 0.4968 | Val Accuracy: 0.7594
# No improvement for 1 epoch(s)
# Epoch 13/15 | Train Loss: 0.4610 | Val Accuracy: 0.8182
# Model saved at epoch 13 with accuracy: 0.8182
# Epoch 14/15 | Train Loss: 0.4358 | Val Accuracy: 0.8182
# No improvement for 1 epoch(s)
# Epoch 15/15 | Train Loss: 0.4119 | Val Accuracy: 0.8075
# No improvement for 2 epoch(s)
# Best Validation Accuracy: 0.8182
# Epoch 1/15 | Train Loss: 1.3712 | Val Accuracy: 0.4011
# Model saved at epoch 1 with accuracy: 0.4011
# Epoch 2/15 | Train Loss: 1.1074 | Val Accuracy: 0.4813
# Model saved at epoch 2 with accuracy: 0.4813
# Epoch 3/15 | Train Loss: 0.9461 | Val Accuracy: 0.5722
# Model saved at epoch 3 with accuracy: 0.5722
# Epoch 4/15 | Train Loss: 0.8672 | Val Accuracy: 0.6043
# Model saved at epoch 4 with accuracy: 0.6043
# Epoch 5/15 | Train Loss: 0.8025 | Val Accuracy: 0.6471
# Model saved at epoch 5 with accuracy: 0.6471
# Epoch 6/15 | Train Loss: 0.7610 | Val Accuracy: 0.6898
# Model saved at epoch 6 with accuracy: 0.6898
# Epoch 7/15 | Train Loss: 0.6780 | Val Accuracy: 0.7540
# Model saved at epoch 7 with accuracy: 0.7540
# Epoch 8/15 | Train Loss: 0.6153 | Val Accuracy: 0.7701
# Model saved at epoch 8 with accuracy: 0.7701
# Epoch 9/15 | Train Loss: 0.5811 | Val Accuracy: 0.7914
# Model saved at epoch 9 with accuracy: 0.7914
# Epoch 10/15 | Train Loss: 0.5054 | Val Accuracy: 0.8128
# Model saved at epoch 10 with accuracy: 0.8128
# Epoch 11/15 | Train Loss: 0.4530 | Val Accuracy: 0.8128
# No improvement for 1 epoch(s)
# Epoch 12/15 | Train Loss: 0.4194 | Val Accuracy: 0.8449
# Model saved at epoch 12 with accuracy: 0.8449
# Epoch 13/15 | Train Loss: 0.4116 | Val Accuracy: 0.8610
# Model saved at epoch 13 with accuracy: 0.8610
# Epoch 14/15 | Train Loss: 0.3597 | Val Accuracy: 0.8449
# No improvement for 1 epoch(s)
# Epoch 15/15 | Train Loss: 0.3506 | Val Accuracy: 0.8824
# Model saved at epoch 15 with accuracy: 0.8824
# Best Validation Accuracy: 0.8824
# Test Relu Accuracy: 0.8064
# Test Gelu Accuracy: 0.8489
# --------------------w2v_lemma_withIDF_withoutStopWords.csv--------------------
# Epoch 1/15 | Train Loss: 1.3490 | Val Accuracy: 0.5241
# Model saved at epoch 1 with accuracy: 0.5241
# Epoch 2/15 | Train Loss: 1.0561 | Val Accuracy: 0.5508
# Model saved at epoch 2 with accuracy: 0.5508
# Epoch 3/15 | Train Loss: 0.8195 | Val Accuracy: 0.6684
# Model saved at epoch 3 with accuracy: 0.6684
# Epoch 4/15 | Train Loss: 0.6826 | Val Accuracy: 0.6417
# No improvement for 1 epoch(s)
# Epoch 5/15 | Train Loss: 0.5864 | Val Accuracy: 0.7059
# Model saved at epoch 5 with accuracy: 0.7059
# Epoch 6/15 | Train Loss: 0.4860 | Val Accuracy: 0.7005
# No improvement for 1 epoch(s)
# Epoch 7/15 | Train Loss: 0.4528 | Val Accuracy: 0.6952
# No improvement for 2 epoch(s)
# Epoch 8/15 | Train Loss: 0.3400 | Val Accuracy: 0.7754
# Model saved at epoch 8 with accuracy: 0.7754
# Epoch 9/15 | Train Loss: 0.3135 | Val Accuracy: 0.7326
# No improvement for 1 epoch(s)
# Epoch 10/15 | Train Loss: 0.2432 | Val Accuracy: 0.7433
# No improvement for 2 epoch(s)
# Epoch 11/15 | Train Loss: 0.2080 | Val Accuracy: 0.7487
# No improvement for 3 epoch(s)
# Early stopping triggered.
# Best Validation Accuracy: 0.7754
# Epoch 1/15 | Train Loss: 1.3584 | Val Accuracy: 0.4064
# Model saved at epoch 1 with accuracy: 0.4064
# Epoch 2/15 | Train Loss: 1.0710 | Val Accuracy: 0.5882
# Model saved at epoch 2 with accuracy: 0.5882
# Epoch 3/15 | Train Loss: 0.8780 | Val Accuracy: 0.6310
# Model saved at epoch 3 with accuracy: 0.6310
# Epoch 4/15 | Train Loss: 0.7610 | Val Accuracy: 0.6524
# Model saved at epoch 4 with accuracy: 0.6524
# Epoch 5/15 | Train Loss: 0.6807 | Val Accuracy: 0.6738
# Model saved at epoch 5 with accuracy: 0.6738
# Epoch 6/15 | Train Loss: 0.5984 | Val Accuracy: 0.6524
# No improvement for 1 epoch(s)
# Epoch 7/15 | Train Loss: 0.5456 | Val Accuracy: 0.6791
# Model saved at epoch 7 with accuracy: 0.6791
# Epoch 8/15 | Train Loss: 0.5162 | Val Accuracy: 0.7112
# Model saved at epoch 8 with accuracy: 0.7112
# Epoch 9/15 | Train Loss: 0.4448 | Val Accuracy: 0.6952
# No improvement for 1 epoch(s)
# Epoch 10/15 | Train Loss: 0.4376 | Val Accuracy: 0.6845
# No improvement for 2 epoch(s)
# Epoch 11/15 | Train Loss: 0.4251 | Val Accuracy: 0.7112
# No improvement for 3 epoch(s)
# Early stopping triggered.
# Best Validation Accuracy: 0.7112
# Test Relu Accuracy: 0.7745
# Test Gelu Accuracy: 0.7340
# --------------------w2v_lemma_withIDF_withStopWords.csv--------------------
# Epoch 1/15 | Train Loss: 1.3657 | Val Accuracy: 0.3048
# Model saved at epoch 1 with accuracy: 0.3048
# Epoch 2/15 | Train Loss: 1.1555 | Val Accuracy: 0.5187
# Model saved at epoch 2 with accuracy: 0.5187
# Epoch 3/15 | Train Loss: 0.9092 | Val Accuracy: 0.6364
# Model saved at epoch 3 with accuracy: 0.6364
# Epoch 4/15 | Train Loss: 0.7642 | Val Accuracy: 0.6738
# Model saved at epoch 4 with accuracy: 0.6738
# Epoch 5/15 | Train Loss: 0.6686 | Val Accuracy: 0.6631
# No improvement for 1 epoch(s)
# Epoch 6/15 | Train Loss: 0.5631 | Val Accuracy: 0.7059
# Model saved at epoch 6 with accuracy: 0.7059
# Epoch 7/15 | Train Loss: 0.4735 | Val Accuracy: 0.7326
# Model saved at epoch 7 with accuracy: 0.7326
# Epoch 8/15 | Train Loss: 0.4117 | Val Accuracy: 0.7433
# Model saved at epoch 8 with accuracy: 0.7433
# Epoch 9/15 | Train Loss: 0.3433 | Val Accuracy: 0.7807
# Model saved at epoch 9 with accuracy: 0.7807
# Epoch 10/15 | Train Loss: 0.3023 | Val Accuracy: 0.7701
# No improvement for 1 epoch(s)
# Epoch 11/15 | Train Loss: 0.2656 | Val Accuracy: 0.7861
# Model saved at epoch 11 with accuracy: 0.7861
# Epoch 12/15 | Train Loss: 0.2369 | Val Accuracy: 0.8075
# Model saved at epoch 12 with accuracy: 0.8075
# Epoch 13/15 | Train Loss: 0.2017 | Val Accuracy: 0.7968
# No improvement for 1 epoch(s)
# Epoch 14/15 | Train Loss: 0.1891 | Val Accuracy: 0.8075
# No improvement for 2 epoch(s)
# Epoch 15/15 | Train Loss: 0.1769 | Val Accuracy: 0.7914
# No improvement for 3 epoch(s)
# Early stopping triggered.
# Best Validation Accuracy: 0.8075
# Epoch 1/15 | Train Loss: 1.3722 | Val Accuracy: 0.2139
# Model saved at epoch 1 with accuracy: 0.2139
# Epoch 2/15 | Train Loss: 1.1708 | Val Accuracy: 0.5080
# Model saved at epoch 2 with accuracy: 0.5080
# Epoch 3/15 | Train Loss: 0.9404 | Val Accuracy: 0.6203
# Model saved at epoch 3 with accuracy: 0.6203
# Epoch 4/15 | Train Loss: 0.8300 | Val Accuracy: 0.6791
# Model saved at epoch 4 with accuracy: 0.6791
# Epoch 5/15 | Train Loss: 0.7248 | Val Accuracy: 0.6845
# Model saved at epoch 5 with accuracy: 0.6845
# Epoch 6/15 | Train Loss: 0.6497 | Val Accuracy: 0.7380
# Model saved at epoch 6 with accuracy: 0.7380
# Epoch 7/15 | Train Loss: 0.5865 | Val Accuracy: 0.6738
# No improvement for 1 epoch(s)
# Epoch 8/15 | Train Loss: 0.4930 | Val Accuracy: 0.7219
# No improvement for 2 epoch(s)
# Epoch 9/15 | Train Loss: 0.4455 | Val Accuracy: 0.7273
# No improvement for 3 epoch(s)
# Early stopping triggered.
# Best Validation Accuracy: 0.7380
# Test Relu Accuracy: 0.7702
# Test Gelu Accuracy: 0.7000
# --------------------w2v_lemma_withoutIdf_withoutStopWords.csv--------------------
# Epoch 1/15 | Train Loss: 1.3801 | Val Accuracy: 0.5561
# Model saved at epoch 1 with accuracy: 0.5561
# Epoch 2/15 | Train Loss: 1.2282 | Val Accuracy: 0.4813
# No improvement for 1 epoch(s)
# Epoch 3/15 | Train Loss: 0.9660 | Val Accuracy: 0.6096
# Model saved at epoch 3 with accuracy: 0.6096
# Epoch 4/15 | Train Loss: 0.8208 | Val Accuracy: 0.6952
# Model saved at epoch 4 with accuracy: 0.6952
# Epoch 5/15 | Train Loss: 0.7353 | Val Accuracy: 0.7326
# Model saved at epoch 5 with accuracy: 0.7326
# Epoch 6/15 | Train Loss: 0.6606 | Val Accuracy: 0.7540
# Model saved at epoch 6 with accuracy: 0.7540
# Epoch 7/15 | Train Loss: 0.6141 | Val Accuracy: 0.7380
# No improvement for 1 epoch(s)
# Epoch 8/15 | Train Loss: 0.5738 | Val Accuracy: 0.7540
# No improvement for 2 epoch(s)
# Epoch 9/15 | Train Loss: 0.5371 | Val Accuracy: 0.7701
# Model saved at epoch 9 with accuracy: 0.7701
# Epoch 10/15 | Train Loss: 0.4659 | Val Accuracy: 0.7754
# Model saved at epoch 10 with accuracy: 0.7754
# Epoch 11/15 | Train Loss: 0.4293 | Val Accuracy: 0.7968
# Model saved at epoch 11 with accuracy: 0.7968
# Epoch 12/15 | Train Loss: 0.3858 | Val Accuracy: 0.7914
# No improvement for 1 epoch(s)
# Epoch 13/15 | Train Loss: 0.3672 | Val Accuracy: 0.7914
# No improvement for 2 epoch(s)
# Epoch 14/15 | Train Loss: 0.3411 | Val Accuracy: 0.8235
# Model saved at epoch 14 with accuracy: 0.8235
# Epoch 15/15 | Train Loss: 0.3132 | Val Accuracy: 0.8128
# No improvement for 1 epoch(s)
# Best Validation Accuracy: 0.8235
# Epoch 1/15 | Train Loss: 1.3767 | Val Accuracy: 0.4813
# Model saved at epoch 1 with accuracy: 0.4813
# Epoch 2/15 | Train Loss: 1.1786 | Val Accuracy: 0.5027
# Model saved at epoch 2 with accuracy: 0.5027
# Epoch 3/15 | Train Loss: 1.0197 | Val Accuracy: 0.5882
# Model saved at epoch 3 with accuracy: 0.5882
# Epoch 4/15 | Train Loss: 0.8987 | Val Accuracy: 0.6096
# Model saved at epoch 4 with accuracy: 0.6096
# Epoch 5/15 | Train Loss: 0.7970 | Val Accuracy: 0.5829
# No improvement for 1 epoch(s)
# Epoch 6/15 | Train Loss: 0.7159 | Val Accuracy: 0.6738
# Model saved at epoch 6 with accuracy: 0.6738
# Epoch 7/15 | Train Loss: 0.6772 | Val Accuracy: 0.7059
# Model saved at epoch 7 with accuracy: 0.7059
# Epoch 8/15 | Train Loss: 0.6192 | Val Accuracy: 0.6738
# No improvement for 1 epoch(s)
# Epoch 9/15 | Train Loss: 0.5856 | Val Accuracy: 0.7380
# Model saved at epoch 9 with accuracy: 0.7380
# Epoch 10/15 | Train Loss: 0.5687 | Val Accuracy: 0.7433
# Model saved at epoch 10 with accuracy: 0.7433
# Epoch 11/15 | Train Loss: 0.5242 | Val Accuracy: 0.7380
# No improvement for 1 epoch(s)
# Epoch 12/15 | Train Loss: 0.5156 | Val Accuracy: 0.7112
# No improvement for 2 epoch(s)
# Epoch 13/15 | Train Loss: 0.4643 | Val Accuracy: 0.7647
# Model saved at epoch 13 with accuracy: 0.7647
# Epoch 14/15 | Train Loss: 0.4534 | Val Accuracy: 0.7594
# No improvement for 1 epoch(s)
# Epoch 15/15 | Train Loss: 0.4292 | Val Accuracy: 0.7540
# No improvement for 2 epoch(s)
# Best Validation Accuracy: 0.7647
# Test Relu Accuracy: 0.7872
# Test Gelu Accuracy: 0.7298
# --------------------w2v_lemma_withoutIdf_withStopWords.csv--------------------
# Epoch 1/15 | Train Loss: 1.3752 | Val Accuracy: 0.3797
# Model saved at epoch 1 with accuracy: 0.3797
# Epoch 2/15 | Train Loss: 1.1535 | Val Accuracy: 0.5187
# Model saved at epoch 2 with accuracy: 0.5187
# Epoch 3/15 | Train Loss: 0.9716 | Val Accuracy: 0.5722
# Model saved at epoch 3 with accuracy: 0.5722
# Epoch 4/15 | Train Loss: 0.8886 | Val Accuracy: 0.6791
# Model saved at epoch 4 with accuracy: 0.6791
# Epoch 5/15 | Train Loss: 0.8000 | Val Accuracy: 0.6364
# No improvement for 1 epoch(s)
# Epoch 6/15 | Train Loss: 0.7443 | Val Accuracy: 0.6952
# Model saved at epoch 6 with accuracy: 0.6952
# Epoch 7/15 | Train Loss: 0.6736 | Val Accuracy: 0.6791
# No improvement for 1 epoch(s)
# Epoch 8/15 | Train Loss: 0.6323 | Val Accuracy: 0.7647
# Model saved at epoch 8 with accuracy: 0.7647
# Epoch 9/15 | Train Loss: 0.5868 | Val Accuracy: 0.7647
# No improvement for 1 epoch(s)
# Epoch 10/15 | Train Loss: 0.5361 | Val Accuracy: 0.8075
# Model saved at epoch 10 with accuracy: 0.8075
# Epoch 11/15 | Train Loss: 0.4947 | Val Accuracy: 0.7914
# No improvement for 1 epoch(s)
# Epoch 12/15 | Train Loss: 0.4807 | Val Accuracy: 0.8128
# Model saved at epoch 12 with accuracy: 0.8128
# Epoch 13/15 | Train Loss: 0.4451 | Val Accuracy: 0.7968
# No improvement for 1 epoch(s)
# Epoch 14/15 | Train Loss: 0.4239 | Val Accuracy: 0.8396
# Model saved at epoch 14 with accuracy: 0.8396
# Epoch 15/15 | Train Loss: 0.3930 | Val Accuracy: 0.8342
# No improvement for 1 epoch(s)
# Best Validation Accuracy: 0.8396
# Epoch 1/15 | Train Loss: 1.3755 | Val Accuracy: 0.3102
# Model saved at epoch 1 with accuracy: 0.3102
# Epoch 2/15 | Train Loss: 1.1407 | Val Accuracy: 0.4920
# Model saved at epoch 2 with accuracy: 0.4920
# Epoch 3/15 | Train Loss: 0.9623 | Val Accuracy: 0.5615
# Model saved at epoch 3 with accuracy: 0.5615
# Epoch 4/15 | Train Loss: 0.8785 | Val Accuracy: 0.6364
# Model saved at epoch 4 with accuracy: 0.6364
# Epoch 5/15 | Train Loss: 0.8219 | Val Accuracy: 0.6203
# No improvement for 1 epoch(s)
# Epoch 6/15 | Train Loss: 0.7841 | Val Accuracy: 0.6471
# Model saved at epoch 6 with accuracy: 0.6471
# Epoch 7/15 | Train Loss: 0.7332 | Val Accuracy: 0.7005
# Model saved at epoch 7 with accuracy: 0.7005
# Epoch 8/15 | Train Loss: 0.6842 | Val Accuracy: 0.6952
# No improvement for 1 epoch(s)
# Epoch 9/15 | Train Loss: 0.6533 | Val Accuracy: 0.7433
# Model saved at epoch 9 with accuracy: 0.7433
# Epoch 10/15 | Train Loss: 0.6044 | Val Accuracy: 0.7807
# Model saved at epoch 10 with accuracy: 0.7807
# Epoch 11/15 | Train Loss: 0.5701 | Val Accuracy: 0.7807
# No improvement for 1 epoch(s)
# Epoch 12/15 | Train Loss: 0.5442 | Val Accuracy: 0.8235
# Model saved at epoch 12 with accuracy: 0.8235
# Epoch 13/15 | Train Loss: 0.5060 | Val Accuracy: 0.7754
# No improvement for 1 epoch(s)
# Epoch 14/15 | Train Loss: 0.4703 | Val Accuracy: 0.8021
# No improvement for 2 epoch(s)
# Epoch 15/15 | Train Loss: 0.4293 | Val Accuracy: 0.7701
# No improvement for 3 epoch(s)
# Early stopping triggered.
# Best Validation Accuracy: 0.8235
# Test Relu Accuracy: 0.8128
# Test Gelu Accuracy: 0.7447
